# %%
name = "Mobashshir"

nameShort = name[0: 3]
nameShort = name[0: -3]  #the index in a string starts from 0 to (length-1)

# %%
print(nameShort)

# %% [markdown]
# # Negative String Slicing

# %%
name = "Mobashshir"

print(name[0:3])

# %%
name.

# %%
# print(name[-4: -1])
print(name[-4: -1])  #your slice is from -1 to -4 → and since Python slicing works left to right, this means the start index (-1) is after the *end index (-4)**.
# convert your negative indices into corresponding positive indices 
print(name[1: 4])

# %%
# If you want the last 3 characters in reverse, you can do:
# string[start : stop : step]

print(name[-1:-4:-1])

# %%
print(name[:4])     # 0, 1, 2, 3

# %%
print(name[:4]) # length -1

# %%
print(name[1:])     #is same as [1:length-1]

# %% [markdown]
# # Slicing with skip Value

# %%
word = "amazing"

word[1: 6: 2]  #mzn
# Out:
# 'mzn'

# %%
word[:7]
# Out:
# 'amazing'

# %%
name = "Mobashshir"
print(name[:1])
print(name[:2])
print(name[:3])
print(name[:4])
print(name[:5])
print(name[:6])
print(name[:7])
print(name[:8])
print(name[:9])
print(name[:10])
# Out:
# M
# Mo
# Mob
# Moba
# Mobas
# Mobash
# Mobashs
# Mobashsh
# Mobashshi
# Mobashshir

# %%
print(name[:-1])
print(name[:-2])
print(name[:-3])
print(name[:-4])
print(name[:-5])
print(name[:-6])
print(name[:-7])
print(name[:-8])
print(name[:-9])
# Out:
# Mobashshi
# Mobashsh
# Mobashs
# Mobash
# Mobas
# Moba
# Mob
# Mo
# M

# %%
print(name[-4 : -1])
# Out:
# shi

# %%
print(name[-4 : -1])
print(name[1 : 3])
print(name[4 :])
# Out:
# shi
# ob
# shshir

# %%
print(name[1:5:2])
print(name[1:7:2])
print(name[1:9:2])
# Out:
# oa
# oah
# oahh

# %%
str = "Machine"
new = str.capitalize()
print(new)
# Out:
# Machine

# %%
str = "banana"
index = str.find("an")
print(index)
# Out:
# 1

# %%
str1 = "apple"
new = str1.find("pp")
print(new)
# Out:
# 1

# %%
str2 = "Ganga"
new2 = str2.find("g")
print(new2)
# Out:
# 3

# %%
str3 = "samsung"
new3 = str3.find("un")
print(new3)
# Out:
# 4

# %%
str4 = "mobashshir"
new4 = str4.find("sh")
print(new4)
# Out:
# 4

# %%
str5 = "nvidia"
new5 = str5.find("i")
print(new5)
# Out:
# 2
